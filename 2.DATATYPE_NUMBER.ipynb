# %% [markdown]
# <h1 style='color:green'>Everything is object in Python(DYNAMIC LANGUAGE)</h1>

# %% [markdown]
#  # COMMONLY USED OPERATORS

# %%
2+3
# Out:
# 5

# %%
3-2
# Out:
# 1

# %%
3*3
# Out:
# 9

# %% [markdown]
# FLOATING DIVISION

# %%
4/3
# Out:
# 1.3333333333333333

# %% [markdown]
# INTEGER DIVISION

# %%
4//3
# Out:
# 1

# %%
int(4/3)
# Out:
# 1

# %%
4**2
# Out:
# 16

# %%
x=5
x+=1
print(x)
# Out:
# 6

# %% [raw]
# Post increment or decrement is not allowed in python
# Because:
#     1.In Python, integers are immutable

# %%
x=5
x++
print(x)
# Out:
#   File "<ipython-input-27-d9d7538ce3ae>", line 2
#     x++
#        ^
# SyntaxError: invalid syntax

# %%
x=5
y=5
print(id(x))
print(id(y))
# Out:
# 140736436740624
# 140736436740624

# %% [raw]
#                 Actually x and y above are actually the same object.
#                 If you incremented x, you would also increment y.
#                 That's why post increment or decrement is not allowed

# %% [markdown]
# #### What about pre increment?

# %%
x=5
y=++x
print(y)
# Out:
# 5

# %% [raw]
# It is not incrementing but not showing any error
#         You know why ?

# %% [raw]
#     In python ++ is not operator
#         + is an operator
#         It actually does like:
#             +(+x) here + is an identity operator
#             so ultimately it is positive x

# %%
+(+x)
# Out:
# 5

# %% [markdown]
# <h1 style='color:blue'> DATA TYPES</h1>

# %% [markdown]
# 1. **Numbers**
#     * int
#     * float
# *  **Strings**
#     * single line string
#     * multi line string (triple quoted string)
# * **List**
# * **Tuple**
# * **Dict**
# * **Set**
# * **Frozen Sets**
# * **Boolean Type**
# * **None Type**

# %% [markdown]
# **Data**
#
#         any meaningfull piece of information
#         Data is wealth
#
#
# **Type** (class, category)
#
#         classification of data to handle it properly
#
#         set of rules imposed on data to define it's category
#
#
# space and functionality

# %% [markdown]
# # NUMBERS

# %%
x = 11
print(type(x), x)
# Out:
# <class 'int'> 11

# %%
x = 9.1
print(type(x), x)
# Out:
# <class 'float'> 9.1

# %%
x = 145 + 112j # j --> iota --> 
print(type(x), x)
# Out:
# <class 'complex'> (145+112j)

# %%
2j * 9j
# Out:
# (-18+0j)

# %% [markdown]
# #####        PYHTON CAN STORE ANY LENGTH OF DATA

# %%
x = 29349837473924798327498273894723894798234893289423984732947237423749832748923789472389473289479837489798472343294792274

# %% [raw]
#                     CASE SENSITIVE

# %%
X
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-b5fec669aca1> in <module>
# ----> 1 X
#
# NameError: name 'X' is not defined

# %%
x
# Out:
# 29349837473924798327498273894723894798234893289423984732947237423749832748923789472389473289479837489798472343294792274

# %%
print(x**100)
# Out:
# ...

# %% [markdown]
# <h1 style='color:blue'>THANK YOU</h1>
